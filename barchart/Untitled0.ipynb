# %%
import pandas as pd

# %%
data = pd.read_csv('https://inventory.data.gov/dataset/032e19b4-5a90-41dc-83ff-6e4cd234f565/resource/38625c3d-5388-4c16-a30f-d105432553a4/download/postscndryunivsrvy2013dirinfo.csv')

# %%
data.shape
# Out:
# (7769, 66)

# %%
data.head()
# Out:
#    UNITID                               INSTNM  \
# 0  100654             Alabama A & M University
# 1  100663  University of Alabama at Birmingham
# 2  100690                   Amridge University
# 3  100706  University of Alabama in Huntsville
# 4  100724             Alabama State University
#
#                              ADDR        CITY STABBR         ZIP  FIPS  \
# 0            4900 Meridian Street      Normal     AL       35762     1
# 1  Administration Bldg Suite 1070  Birmingham     AL  35294-0110     1
# 2                  1200 Taylor Rd  Montgomery     AL  36117-3553     1
# 3                 301 Sparkman Dr  Huntsville     AL       35899     1
# 4            915 S Jackson Street  Montgomery     AL  36104-0271     1
#
#    OBEREG                   CHFNM   CHFTITLE    ...      CSA NECTA  F1SYSTYP  \
# 0       5  Dr. Andrew Hugine, Jr.  President    ...      290    -2         2
# 1       5            Ray L. Watts  President    ...      142    -2         1
# ...

# %%
states = data.groupby('STABBR').count()

# %%
states = states['UNITID']

# %%
states
# Out:
# STABBR
# AK         12
# AL         93
# AR         88
# AS          1
# AZ        146
# CA        789
# CO        141
# CT        100
# DC         25
# DE         21
# FL        402
# FM          1
# GA        199
# GU          3
# HI         28
# IA         96
# ID         44
# IL        320
# IN        139
# KS         96
# KY        117
# LA        128
# MA        197
# MD        105
# ME         43
# MH          1
# MI        204
# MN        149
# MO        226
# MP          1
# MS         64
# MT         31
# NC        199
# ND         30
# NE         53
# NH         44
# NJ        173
# NM         52
# NV         53
# NY        481
# OH        383
# OK        149
# OR         99
# PA        406
# PR        158
# PW          1
# RI         24
# SC        113
# SD         31
# TN        190
# TX        479
# UT         88
# VA        178
# VI          1
# VT         28
# WA        128
# WI        127
# WV         79
# WY         12
# Name: UNITID, Length: 59, dtype: int64

# %%
states = states.drop(['AS','DC','FM','GU','MH','MP','PW','PR','VI'])

# %%
states.to_csv('states.csv')
